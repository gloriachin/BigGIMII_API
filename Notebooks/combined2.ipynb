# %%
import BigGim2
import requests
import pandas as pd

# %%
meta_mut_kp = BigGim2.Query_fields_Mut_Freq_KP()
(meta_mut_kp)
# Out:
# {'association': {'index': True, 'type': 'object'},
#  'association.edge_label': {'index': True, 'type': 'keyword'},
#  'association.freq_by_case': {'index': True, 'type': 'float'},
#  'association.freq_by_sample': {'index': True, 'type': 'float'},
#  'association.no_mut_cases': {'index': True, 'type': 'integer'},
#  'association.no_mut_samples': {'index': True, 'type': 'integer'},
#  'association.relation_name': {'index': True, 'type': 'keyword'},
#  'object': {'index': True, 'type': 'object'},
#  'object.MONDO': {'index': True,
#   'searched_by_default': True,
#   'type': 'keyword'},
#  'object.id': {'index': True, 'type': 'keyword'},
#  'object.tcga_name': {'index': True, 'type': 'keyword'},
#  'object.type': {'index': True, 'type': 'keyword'},
#  'subject': {'index': True, 'type': 'object'},
#  'subject.SYMBOL': {'index': True,
#   'searched_by_default': True,
#   'type': 'keyword'},
#  'subject.id': {'index': True, 'type': 'keyword'},
#  'subject.type': {'index': True, 'type': 'keyword'}}

# %%
Query_disease = 'MONDO:0005061'

# %%
Query1 = {"object.id":"%22"+Query_disease+"%22",
         "association.freq_by_case":"%3E0.05",
         #"subject.SYMBOL":Query_Gene
        }

# %%
result = BigGim2.Query_Mut_Freq_KP(Query1)  #Jason format
result_df1 = BigGim2.format_result_Mut_Freq(result) #Pandas DataFrame format
result_df1.sort_values(by = ['edge_freq_by_case'], ascending = False)
# Out:
# https://biothings.ncats.io/tcga_mut_freq_kp/query?q=object.id:%22MONDO:0005061%22%20AND%20association.freq_by_case:%3E0.05&size=1000
#          subject_id subject_symbol subject_type      object_id object_name  \
# 153     SYMBOL:TP53           TP53         gene  MONDO:0005061        LUAD
# 647      SYMBOL:TTN            TTN         gene  MONDO:0005061        LUAD
# 411    SYMBOL:MUC16          MUC16         gene  MONDO:0005061        LUAD
# 667    SYMBOL:CSMD3          CSMD3         gene  MONDO:0005061        LUAD
# 319     SYMBOL:RYR2           RYR2         gene  MONDO:0005061        LUAD
# ..              ...            ...          ...            ...         ...
# 321      SYMBOL:TPR            TPR         gene  MONDO:0005061        LUAD
# 511    SYMBOL:AKAP9          AKAP9         gene  MONDO:0005061        LUAD
# 314  SYMBOL:RUNX1T1        RUNX1T1         gene  MONDO:0005061        LUAD
# 148  SYMBOL:PCDHB14        PCDHB14         gene  MONDO:0005061        LUAD
# 336    SYMBOL:FNDC1          FNDC1         gene  MONDO:0005061        LUAD
#
#     object_type                                         edge_label  \
# 153     disease  gene_has_variant_that_contributes_to_disease_a...
# 647     disease  gene_has_variant_that_contributes_to_disease_a...
# 411     disease  gene_has_variant_that_contributes_to_disease_a...
# 667     disease  gene_has_variant_that_contributes_to_disease_a...
# 319     disease  gene_has_variant_that_contributes_to_disease_a...
# ..          ...                                                ...
# 321     disease  gene_has_variant_that_contributes_to_disease_a...
# 511     disease  gene_has_variant_that_contributes_to_disease_a...
# 314     disease  gene_has_variant_that_contributes_to_disease_a...
# 148     disease  gene_has_variant_that_contributes_to_disease_a...
# 336     disease  gene_has_variant_that_contributes_to_disease_a...
#
#      edge_freq_by_case  edge_freq_by_sample
# 153           0.511464             0.513181
# 647           0.483245             0.483304
# 411           0.423280             0.423550
# 667           0.398589             0.400703
# 319           0.382716             0.383128
# ..                 ...                  ...
# 321           0.051146             0.050967
# 511           0.051146             0.050967
# 314           0.051146             0.050967
# 148           0.051146             0.054482
# 336           0.051146             0.050967
#
# [723 rows x 9 columns]

# %%
#meta_DrugResponse_KP = BigGim2.Query_fields_DrugResponse_KP()
#meta_DrugResponse_KP

# %%
Query2 = {"subject.SYMBOL":"TP53",  #Query by gene symbol
         #"subject.id": "%22NCBIGene:4893%22" #Query by id
         #"association.effect_size": "%3C%2D1", #effect_size, %3C: <; %2D1: -1
         #"association.effect_size": "%3C0", #effect_size, %3C: <; %2D1: -1
         #"association.pvalue": "%3C0.05", ##p value from t-test 
         "association.context.disease.mondo": "%22"+Query_disease+"%22", #Disease type
         "association.median_ic50_mut":"%3C0", #The median value of IC50 in the mutated group
         "association.median_ic50_wt":"%3C0"  ##The median value of IC50 in the wild type group
         # "object.name":"Afatinib", #Query by drug
        }

# %%
result = BigGim2.Query_DrugResponse_KP(Query2)  #Jason format
result_df2 = BigGim2.format_result_DrugResponse_KP(result) #Pandas DataFrame format
result_df2.sort_values(by = ['object_name']) #View the results
# Out:
# https://biothings.ncats.io/drug_response_kp/query?q=subject.SYMBOL:TP53%20AND%20association.context.disease.mondo:%22MONDO:0005061%22%20AND%20association.median_ic50_mut:%3C0%20AND%20association.median_ic50_wt:%3C0&size=1000
#    subject_id subject_symbol subject_type          object_id   object_name  \
# 11       7157           TP53         Gene     PUBCHEM:151069        17-AAG
# 9        7157           TP53         Gene  PUBCHEM:135545855        AUY922
# 12       7157           TP53         Gene   PUBCHEM:67077825       AZD7762
# 25       7157           TP53         Gene     PUBCHEM:440577  Bryostatin 1
# 20       7157           TP53         Gene      PUBCHEM:24360  Camptothecin
# 3        7157           TP53         Gene     PUBCHEM:148124     Docetaxel
# 0        7157           TP53         Gene      PUBCHEM:31703   Doxorubicin
# 18       7157           TP53         Gene     PUBCHEM:300471    Elesclomol
# 23       7157           TP53         Gene        CHEBI:31550  Epothilone B
# 24       7157           TP53         Gene   PUBCHEM:25167777    GSK2126458
# 13       7157           TP53         Gene      PUBCHEM:60750   Gemcitabine
# 14       7157           TP53         Gene   PUBCHEM:25222038        JNK-9L
# 15       7157           TP53         Gene    PUBCHEM:6445533        LAQ824
# 10       7157           TP53         Gene    PUBCHEM:9829523   Midostaurin
# 21       7157           TP53         Gene        CHEBI:71952    NVP-BEZ235
# 26       7157           TP53         Gene    PUBCHEM:9826528    PD-0325901
# 16       7157           TP53         Gene   PUBCHEM:58525121    QL-VIII-58
# 17       7157           TP53         Gene    PUBCHEM:6851740     SB-715992
# 4        7157           TP53         Gene         CHEBI:8988         SN-38
# 22       7157           TP53         Gene         name:TW 37         TW 37
# 5        7157           TP53         Gene     PUBCHEM:148191  Temsirolimus
# 7        7157           TP53         Gene      PUBCHEM:49926  Thapsigargin
# 19       7157           TP53         Gene   PUBCHEM:11707110    Trametinib
# 8        7157           TP53         Gene      PUBCHEM:13342   Vinblastine
# 6        7157           TP53         Gene    PUBCHEM:5311497   Vinorelbine
# 2        7157           TP53         Gene   PUBCHEM:11178236         YM155
# 1        7157           TP53         Gene        name:rTRAIL        rTRAIL
#
#           object_type  edge_label edge_context_disease  edge_confidence_p  \
# 11  ChemicalSubstance  related_to        MONDO:0005061           0.139063
# 9   ChemicalSubstance  related_to        MONDO:0005061           0.095717
# 12  ChemicalSubstance  related_to        MONDO:0005061           0.421089
# 25  ChemicalSubstance  related_to        MONDO:0005061           0.361062
# 20  ChemicalSubstance  related_to        MONDO:0005061           0.981737
# 3   ChemicalSubstance  related_to        MONDO:0005061           0.741837
# 0   ChemicalSubstance  related_to        MONDO:0005061           0.375769
# 18  ChemicalSubstance  related_to        MONDO:0005061           0.079745
# 23  ChemicalSubstance  related_to        MONDO:0005061           0.102041
# 24  ChemicalSubstance  related_to        MONDO:0005061           0.286051
# 13  ChemicalSubstance  related_to        MONDO:0005061           0.129473
# 14  ChemicalSubstance  related_to        MONDO:0005061           0.416062
# 15  ChemicalSubstance  related_to        MONDO:0005061           0.276904
# 10  ChemicalSubstance  related_to        MONDO:0005061           0.643594
# 21  ChemicalSubstance  related_to        MONDO:0005061           0.604750
# 26  ChemicalSubstance  related_to        MONDO:0005061           0.031009
# 16  ChemicalSubstance  related_to        MONDO:0005061           0.258610
# 17  ChemicalSubstance  related_to        MONDO:0005061           0.785522
# 4   ChemicalSubstance  related_to        MONDO:0005061           0.556356
# 22  ChemicalSubstance  related_to        MONDO:0005061           0.030295
# 5   ChemicalSubstance  related_to        MONDO:0005061           0.123953
# 7   ChemicalSubstance  related_to        MONDO:0005061           0.642887
# 19  ChemicalSubstance  related_to        MONDO:0005061           0.095207
# 8   ChemicalSubstance  related_to        MONDO:0005061           0.513022
# 6   ChemicalSubstance  related_to        MONDO:0005061           0.697810
# 2   ChemicalSubstance  related_to        MONDO:0005061           0.430161
# 1   ChemicalSubstance  related_to        MONDO:0005061           0.317276
#
#     edge_effect_size  edge_median_ic50_wt  edge_median_ic50_mut  \
# 11          0.586264            -1.811186             -1.686373
# 9          -0.659006            -2.851348             -3.419779
# 12          0.302967            -0.703366             -0.216342
# 25         -0.355673            -2.613446             -3.002387
# 20          0.008575            -3.964034             -3.697361
# 3           0.123212            -5.180695             -5.198623
# 0          -0.345636            -1.900166             -2.334091
# 18          0.666530            -4.399971             -3.051480
# 23         -0.642277            -3.719970             -5.487700
# 24          0.395418            -3.337591             -2.298986
# 13         -0.596190            -0.726722             -2.994190
# 14          0.316368            -0.578489             -0.221624
# 15         -0.426202            -1.856412             -2.631798
# 10         -0.180085            -0.181873             -0.170404
# 21          0.204351            -2.241499             -2.465023
# 26          0.866771            -2.281492             -0.794125
# 16          0.503493            -1.539056             -1.307076
# 17          0.100524            -0.735036             -1.024901
# 4           0.207441            -4.226896             -3.913909
# 22          0.781700            -0.969272             -0.397012
# 5           0.586892            -2.223725             -1.487378
# 7          -0.179929            -3.772120             -4.742133
# 19          0.598015            -2.443501             -1.669072
# 8           0.245271            -4.019701             -3.956969
# 6          -0.150756            -3.831413             -4.318012
# 2           0.291346            -4.559482             -4.584832
# 1           0.356587            -1.860526             -0.548316
#
#     edge_confidence_sample_size  edge_confidence_mut_size  \
# 11                           63                        45
# 9                            63                        50
# 12                           63                        43
# 25                           63                        50
# 20                           63                        43
# 3                            63                        43
# 0                            63                        50
# 18                           63                        43
# 23                           63                        50
# 24                           63                        51
# 13                           63                        50
# 14                           63                        50
# 15                           63                        50
# 10                           63                        50
# 21                           63                        45
# 26                           63                        45
# 16                           63                        27
# 17                           63                        51
# 4                            63                        51
# 22                           63                        50
# 5                            63                        43
# 7                            63                        50
# 19                           63                        49
# 8                            63                        43
# 6                            63                        50
# 2                            63                        51
# 1                            63                        49
#
#     edge_confidence_wt_size
# 11                        8
# 9                         8
# 12                        9
# 25                        8
# 20                        9
# 3                         9
# 0                         8
# 18                        9
# 23                        8
# 24                        9
# 13                        8
# 14                        8
# 15                        8
# 10                        8
# 21                        8
# 26                        8
# 16                        7
# 17                        9
# 4                        10
# 22                       10
# 5                         9
# 7                         8
# 19                       10
# 8                         9
# 6                         8
# 2                         9
# 1                        10

# %%
list(result_df2['object_name'])
# Out:
# ['Doxorubicin',
#  'rTRAIL',
#  'YM155',
#  'Docetaxel',
#  'SN-38',
#  'Temsirolimus',
#  'Vinorelbine',
#  'Thapsigargin',
#  'Vinblastine',
#  'AUY922',
#  'Midostaurin',
#  '17-AAG',
#  'AZD7762',
#  'Gemcitabine',
#  'JNK-9L',
#  'LAQ824',
#  'QL-VIII-58',
#  'SB-715992',
#  'Elesclomol',
#  'Trametinib',
#  'Camptothecin',
#  'NVP-BEZ235',
#  'TW 37',
#  'Epothilone B',
#  'GSK2126458',
#  'Bryostatin 1',
#  'PD-0325901']
