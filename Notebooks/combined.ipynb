# %%
import BigGim2
import requests
import pandas as pd

# %%
#meta_mut_kp = BigGim2.Query_fields_Mut_Freq_KP()
#(meta_mut_kp)

# %%
Query_Gene = 'EGFR'

# %%
Query1 = {#"object.id":"%22MONDO:0018177%22",
         "association.freq_by_case":"%3E0.05",
         #"association.freq_by_case":"%3E0.1",
         "subject.SYMBOL":Query_Gene
        }

# %%
result = BigGim2.Query_Mut_Freq_KP(Query1)  #Jason format
result_df1 = BigGim2.format_result_Mut_Freq(result) #Pandas DataFrame format
result_df1.sort_values(by = ['edge_freq_by_case'], ascending = False)
# Out:
# https://biothings.ncats.io/tcga_mut_freq_kp/query?q=association.freq_by_case:%3E0.05%20AND%20subject.SYMBOL:EGFR&size=1000
#     subject_id subject_symbol subject_type      object_id object_name  \
# 0  SYMBOL:EGFR           EGFR         gene  MONDO:0018177         GBM
# 2  SYMBOL:EGFR           EGFR         gene  MONDO:0005061        LUAD
# 4  SYMBOL:EGFR           EGFR         gene  MONDO:0005012        SKCM
# 3  SYMBOL:EGFR           EGFR         gene  MONDO:0005499         LGG
# 1  SYMBOL:EGFR           EGFR         gene  MONDO:0000553        UCEC
#
#   object_type                                         edge_label  \
# 0     disease  gene_has_variant_that_contributes_to_disease_a...
# 2     disease  gene_has_variant_that_contributes_to_disease_a...
# 4     disease  gene_has_variant_that_contributes_to_disease_a...
# 3     disease  gene_has_variant_that_contributes_to_disease_a...
# 1     disease  gene_has_variant_that_contributes_to_disease_a...
#
#    edge_freq_by_case  edge_freq_by_sample
# 0           0.234097             0.235732
# 2           0.126984             0.126538
# 4           0.072961             0.072650
# 3           0.070312             0.068441
# 1           0.067925             0.067797

# %%
#meta_DrugResponse_KP = BigGim2.Query_fields_DrugResponse_KP()
#meta_DrugResponse_KP

# %%
Query2 = {"subject.SYMBOL":Query_Gene,  #Query by gene symbol
         #"subject.id": "%22NCBIGene:4893%22" #Query by id
        # "association.effect_size": "%3C%2D1", #effect_size, %3C: <; %2D1: -1
         "association.effect_size": "%3C0", #effect_size, %3C: <; %2D1: -1
         "association.pvalue": "%3C0.05", ##p value from t-test 
         #"association.context.disease.mondo": "%22MONDO:0005061%22", #Disease type
         "association.median_ic50_mut":"%3C0", #The median value of IC50 in the mutated group
         #"association.median_ic50_wt":"%3E0"  ##The median value of IC50 in the wild type group
        # "object.name":"Afatinib", #Query by drug
        }

# %%
result = BigGim2.Query_DrugResponse_KP(Query2)  #Jason format
result_df2 = BigGim2.format_result_DrugResponse_KP(result) #Pandas DataFrame format
result_df2.sort_values(by = ['object_name']) #View the results
# Out:
# https://biothings.ncats.io/drug_response_kp/query?q=subject.SYMBOL:EGFR%20AND%20association.effect_size:%3C0%20AND%20association.pvalue:%3C0.05%20AND%20association.median_ic50_mut:%3C0&size=1000
#   subject_id subject_symbol subject_type                      object_id  \
# 3       1956           EGFR         Gene               PUBCHEM:57519523
# 4       1956           EGFR         Gene                 PUBCHEM:123631
# 0       1956           EGFR         Gene                 PUBCHEM:126941
# 1       1956           EGFR         Gene  CHEMBL.COMPOUND:CHEMBL2107358
# 2       1956           EGFR         Gene                 PUBCHEM:159324
#
#           object_name        object_type  edge_label  \
# 3            Afatinib  ChemicalSubstance  related_to
# 4           Gefitinib  ChemicalSubstance  related_to
# 0        Methotrexate  ChemicalSubstance  related_to
# 1  Obatoclax Mesylate  ChemicalSubstance  related_to
# 2          Tipifarnib  ChemicalSubstance  related_to
#
#              edge_context_disease  edge_confidence_p  edge_effect_size  \
# 3                   MONDO:0005061           0.000013         -2.180000
# 4                   MONDO:0005061           0.001952         -1.497063
# 0                   MONDO:0005170           0.031477         -1.543391
# 1  [MONDO:0003093, MONDO:0005580]           0.042948         -1.186224
# 2  [MONDO:0003093, MONDO:0005580]           0.039579         -1.208813
#
#    edge_median_ic50_wt  edge_median_ic50_mut  edge_confidence_sample_size  \
# 3             1.189939             -2.102841                           63
# 4             1.308749             -0.110006                           63
# 0            -1.574933             -3.618622                           18
# 1            -1.630680             -3.467816                           35
# 2             0.952282             -0.149451                           35
#
#    edge_confidence_mut_size  edge_confidence_wt_size
# 3                         6                       46
# 4                         6                       46
# 0                         3                       15
# 1                         4                       23
# 2                         4                       23
